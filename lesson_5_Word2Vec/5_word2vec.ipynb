# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
    """Download a file if not present, and make sure it's the right size."""
    if not os.path.exists(filename):
        filename, _ = urlretrieve(url + filename, filename)
    statinfo = os.stat(filename)
    if statinfo.st_size == expected_bytes:
        print('Found and verified %s' % filename)
    else:
        print(statinfo.st_size)
        raise Exception('Failed to verify ' + filename + '. Can you get to it with a browser?')
    return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
    """Extract the first file enclosed in a zip file as a list of words"""
    with zipfile.ZipFile(filename) as f:
        data = tf.compat.as_str(f.read(f.namelist()[0])).split()
    return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
    count = [['UNK', -1]]
    count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
    dictionary = dict()
    for word, _ in count:
        dictionary[word] = len(dictionary)
    data = list()
    unk_count = 0
    for word in words:
        if word in dictionary:
            index = dictionary[word]
        else:
            index = 0  # dictionary['UNK']
            unk_count = unk_count + 1
        data.append(index)
    count[0][1] = unk_count
    reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
    return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5234, 3081, 12, 6, 195, 2, 3134, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
    global data_index
    assert batch_size % num_skips == 0
    assert num_skips <= 2 * skip_window
    batch = np.ndarray(shape=(batch_size), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    span = 2 * skip_window + 1 # [ skip_window target skip_window ]
    buffer = collections.deque(maxlen=span)
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    for i in range(batch_size // num_skips):
        target = skip_window  # target label at the center of the buffer
        targets_to_avoid = [ skip_window ]
        for j in range(num_skips):
            while target in targets_to_avoid:
                target = random.randint(0, span - 1)
            targets_to_avoid.append(target)
            batch[i * num_skips + j] = buffer[skip_window]
            labels[i * num_skips + j, 0] = buffer[target]
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'originated', 'a', 'as', 'term', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['term', 'anarchism', 'a', 'originated', 'as', 'term', 'originated', 'of']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

    # Input data.
    train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
    # Variables.
    embeddings = tf.Variable(tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    softmax_weights = tf.Variable(
        tf.truncated_normal([vocabulary_size, embedding_size],stddev=1.0 / math.sqrt(embedding_size))
    )
    softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
    # Model.
    # Look up embeddings for inputs.
    embed = tf.nn.embedding_lookup(embeddings, train_dataset)
    # Compute the softmax loss, using a sample of the negative labels each time.
    loss = tf.reduce_mean(
        tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                                   labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

    # Optimizer.
    # Note: The optimizer will optimize the softmax_weights AND the embeddings.
    # This is because the embeddings are defined as a variable quantity and the
    # optimizer's `minimize` method will by default modify all variable quantities 
    # that contribute to the tensor it is passed.
    # See docs on `tf.train.Optimizer.minimize()` for more details.
    optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
    # Compute the similarity between minibatch examples and all embeddings.
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings, valid_dataset)
    similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
# %%time
num_steps = 100001

with tf.Session(graph=graph) as session:
    tf.global_variables_initializer().run()
    print('Initialized')
    average_loss = 0
    for step in range(num_steps):
        batch_data, batch_labels = generate_batch(batch_size, num_skips, skip_window)
        feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
        _, l = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += l
        if step % 2000 == 0:
            if step > 0:
                average_loss = average_loss / 2000
            # The average loss is an estimate of the loss over the last 2000 batches.
            print('Average loss at step %d: %f' % (step, average_loss))
            average_loss = 0
        # note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 10000 == 0:
            sim = similarity.eval()
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8 # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k+1]
                log = 'Nearest to %s:' % valid_word
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log = '%s %s,' % (log, close_word)
                print(log)
    final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.889320
# Nearest to with: transcribe, simd, leopoldo, vilified, seabirds, louth, itis, says,
# Nearest to while: dock, pepin, southey, commodities, sohn, inflatable, outlandish, hippocampus,
# Nearest to who: authorship, dirac, zetalisp, scytale, counter, broncos, sanh, jref,
# Nearest to war: eubulides, trinomial, common, maximized, organist, constitution, unattractive, mop,
# Nearest to three: ecommerce, maghreb, photius, strategos, megawatts, venom, adaptable, thyssen,
# Nearest to states: womanhood, antidote, thermonuclear, troopers, octets, sebasti, ravine, worden,
# Nearest to or: terrence, bhutto, metallica, convoys, amorites, ite, dome, brine,
# Nearest to he: suffragist, overwritten, etc, ferruccio, evangelicalism, prefixed, ev, uiuc,
# Nearest to have: tba, henry, cyclonic, bartle, tamarin, moltke, othniel, demonstrative,
# Nearest to use: mathew, kista, billet, mischief, khazar, thorax, mutate, nozick,
# Nearest to history: leahy, lodovico, bernhard, mps, sister, perfecti, homerun, cilia,
# Nearest to six: thuringiensis, underwood, cops, quack, skinny, musicbrainz, kevlar, postel,
# Nearest to when: couples, dynasty, malinche, kaiser, carboxylic, pronounced, bsi, sponsorship,
# Nearest to th: chairmen, ancien, crumbs, customizable, initiator, uptake, sobriquet, extent,
# Nearest to will: seizes, airships, oceans, emeritus, pel, journals, startling, tallest,
# Nearest to years: awry, prost, slab, ruse, assessments, deadliest, bebe, formalist,
# Average loss at step 2000: 4.367568
# Average loss at step 4000: 3.870254
# Average loss at step 6000: 3.797857
# Average loss at step 8000: 3.689655
# Average loss at step 10000: 3.613498
# Nearest to with: in, on, using, for, between, impedance, by, seabirds,
# Nearest to while: outlandish, sohn, stiles, garibaldi, scalpel, southey, rosette, esiason,
# Nearest to who: he, unclear, and, there, which, angevin, bedrock, they,
# Nearest to war: dove, eubulides, common, mop, hindsight, original, greenville, superconducting,
# Nearest to three: four, five, six, eight, two, seven, nine, zero,
# Nearest to states: thermonuclear, hurdler, colleagues, geddy, troopers, antidote, ravine, assimilated,
# Nearest to or: and, ite, than, martyr, geats, baroque, smyrnaeans, aziz,
# Nearest to he: it, they, she, who, uiuc, evangelicalism, ev, there,
# Nearest to have: had, has, be, are, rlc, were, tba, ps,
# Nearest to use: kista, nth, phylogenetics, anointing, subtraction, mathew, hierarchy, mutate,
# Nearest to history: sister, deleting, dispossessed, lodovico, leahy, mps, hovering, meadows,
# Nearest to six: seven, eight, four, five, three, nine, zero, two,
# Nearest to when: where, malinche, if, gale, emblems, dynasty, finished, anaximenes,
# Nearest to th: chairmen, ancien, greedy, customizable, volkov, medica, renal, sobriquet,
# Nearest to will: would, shrugged, can, tallest, seizes, popularizer, account, journals,
# Nearest to years: assessments, factbook, awry, brant, screw, mythologie, gbit, slab,
# Average loss at step 12000: 3.604734
# Average loss at step 14000: 3.571155
# Average loss at step 16000: 3.415115
# Average loss at step 18000: 3.458262
# Average loss at step 20000: 3.540190
# Nearest to with: between, for, in, impedance, using, against, by, simd,
# Nearest to while: rosette, outlandish, sohn, from, are, garibaldi, broadway, psychopathic,
# Nearest to who: he, which, they, also, never, there, then, acme,
# Nearest to war: dove, constitution, hindsight, mop, arab, real, rochester, trinomial,
# Nearest to three: four, six, five, seven, two, eight, zero, nine,
# Nearest to states: thermonuclear, hurdler, troopers, colleagues, geddy, bombing, meteorite, reformed,
# Nearest to or: and, than, beekeeping, ite, fairchild, influences, fully, palazzo,
# Nearest to he: it, she, they, who, there, but, gaeltacht, also,
# Nearest to have: had, has, be, were, are, rlc, centaurus, ps,
# Nearest to use: nth, phylogenetics, subtraction, kista, mathew, hierarchy, til, nozick,
# Nearest to history: deleting, leahy, hovering, mandibles, earle, sister, resources, hamster,
# Nearest to six: eight, seven, nine, five, four, three, zero, two,
# Nearest to when: if, where, malinche, gale, was, that, snout, at,
# Nearest to th: chairmen, ancien, volkov, greedy, hexadecimal, deg, customizable, vogue,
# Nearest to will: would, can, may, but, to, must, might, shrugged,
# Nearest to years: leverage, gbit, assessments, blenheim, screams, mythologie, florin, avoiding,
# Average loss at step 22000: 3.501713
# Average loss at step 24000: 3.489474
# Average loss at step 26000: 3.479301
# Average loss at step 28000: 3.481352
# Average loss at step 30000: 3.505604
# Nearest to with: between, using, against, impedance, by, in, when, for,
# Nearest to while: although, psychopathic, is, transliteration, when, before, rosette, broadway,
# Nearest to who: he, they, there, which, never, also, it, barks,
# Nearest to war: hindsight, arab, constitution, botanicals, dove, beagles, sefer, patsy,
# Nearest to three: four, five, seven, two, eight, six, nine, zero,
# Nearest to states: thermonuclear, hurdler, troopers, madness, nations, meteorite, gloster, milos,
# Nearest to or: and, than, mondegreen, diminution, martyr, lix, baroque, lowly,
# Nearest to he: she, it, they, who, there, gaeltacht, never, but,
# Nearest to have: had, has, are, be, were, rlc, centaurus, include,
# Nearest to use: subtraction, phylogenetics, pete, nth, greeting, mathew, strangled, centro,
# Nearest to history: deleting, ades, hokkaido, mandibles, earle, hovering, boys, php,
# Nearest to six: eight, four, seven, five, nine, three, two, zero,
# Nearest to when: if, where, before, cryonicists, after, was, however, gale,
# Nearest to th: eight, ancien, chairmen, six, racetrack, zero, nine, volkov,
# Nearest to will: would, can, may, could, must, might, should, to,
# Nearest to years: gbit, leverage, times, blenheim, fabien, florin, factbook, dyadic,
# Average loss at step 32000: 3.506957
# Average loss at step 34000: 3.492634
# Average loss at step 36000: 3.457883
# Average loss at step 38000: 3.297873
# Average loss at step 40000: 3.431630
# Nearest to with: between, insubordination, using, impedance, when, by, warranted, averroes,
# Nearest to while: although, before, are, but, psychopathic, like, were, transliteration,
# Nearest to who: which, he, there, that, they, also, barks, often,
# Nearest to war: arab, patsy, etymological, furniture, packet, constitution, hindsight, during,
# Nearest to three: four, seven, two, six, five, eight, nine, zero,
# Nearest to states: nations, kingdom, madness, state, troopers, christiansen, tumbling, mercenaries,
# Nearest to or: and, than, a, to, transliteration, rgensen, but, is,
# Nearest to he: she, it, they, there, who, but, originally, ev,
# Nearest to have: had, has, be, were, are, include, rlc, ps,
# Nearest to use: kidneys, guis, hierarchy, propulsion, recognize, lisboa, strangled, using,
# Nearest to history: culture, ades, deleting, mandibles, cubana, programmer, forms, hokkaido,
# Nearest to six: four, five, seven, eight, nine, three, two, zero,
# Nearest to when: if, before, where, cryonicists, after, during, malinche, gale,
# Nearest to th: eight, ancien, racetrack, chairmen, mobster, six, marriott, seven,
# Nearest to will: would, can, could, may, must, might, should, cannot,
# Nearest to years: months, days, gbit, times, decades, year, florin, fabien,
# Average loss at step 42000: 3.435851
# Average loss at step 44000: 3.451259
# Average loss at step 46000: 3.451763
# Average loss at step 48000: 3.357207
# Average loss at step 50000: 3.381721
# Nearest to with: between, impedance, averroes, using, ary, thriving, autocracy, cnidarians,
# Nearest to while: although, when, before, where, however, but, though, and,
# Nearest to who: he, which, they, she, barks, there, never, also,
# Nearest to war: arab, hindsight, koestler, patsy, packet, stunt, furniture, etymological,
# Nearest to three: six, four, seven, eight, five, two, nine, zero,
# Nearest to states: nations, kingdom, state, madness, stalin, trap, geddy, meteorite,
# Nearest to or: and, than, exponent, unattractive, hysteria, alfa, pics, harsher,
# Nearest to he: she, it, they, who, there, this, appeasement, we,
# Nearest to have: had, has, were, are, be, who, having, centaurus,
# Nearest to use: support, lisboa, beginning, hierarchy, mutate, propulsion, fall, amounts,
# Nearest to history: deleting, mandibles, ades, bot, harvey, news, brainstem, cubana,
# Nearest to six: seven, eight, four, nine, five, three, two, zero,
# Nearest to when: if, before, after, where, while, during, though, however,
# Nearest to th: racetrack, ancien, rd, six, zero, mobster, four, marriott,
# Nearest to will: would, can, could, may, must, should, might, cannot,
# Nearest to years: days, months, gbit, times, year, decades, florin, dyadic,
# Average loss at step 52000: 3.437879
# Average loss at step 54000: 3.430173
# Average loss at step 56000: 3.434506
# Average loss at step 58000: 3.396402
# Average loss at step 60000: 3.390958
# Nearest to with: between, laced, averroes, using, by, when, impedance, cn,
# Nearest to while: although, when, before, after, though, objectivist, savers, where,
# Nearest to who: he, which, barks, now, never, she, manar, quintessential,
# Nearest to war: hindsight, arab, furniture, packet, stunt, koestler, factbook, patsy,
# Nearest to three: five, four, six, seven, eight, two, nine, zero,
# Nearest to states: nations, kingdom, countries, state, governments, troopers, milos, union,
# Nearest to or: and, than, rubbed, unattractive, outage, for, piran, rgensen,
# Nearest to he: she, it, they, who, there, appeasement, suggest, ejective,
# Nearest to have: had, has, are, were, be, require, include, including,
# Nearest to use: support, hierarchy, kidneys, require, range, mutate, guis, lisboa,
# Nearest to history: list, cubana, resources, deleting, mandibles, geography, ades, politics,
# Nearest to six: eight, four, seven, five, nine, three, zero, two,
# Nearest to when: if, before, after, where, while, although, though, during,
# Nearest to th: rd, six, five, nine, seven, racetrack, four, ft,
# Nearest to will: would, can, may, could, must, should, might, cannot,
# Nearest to years: days, months, times, decades, year, gbit, seconds, weeks,
# Average loss at step 62000: 3.243900
# Average loss at step 64000: 3.252331
# Average loss at step 66000: 3.410407
# Average loss at step 68000: 3.394386
# Average loss at step 70000: 3.358987
# Nearest to with: between, impedance, pectoral, laced, sidonia, averroes, using, gand,
# Nearest to while: although, before, though, after, and, however, when, including,
# Nearest to who: he, barks, never, she, now, which, mendelssohn, angilbert,
# Nearest to war: arab, factbook, koestler, furniture, hindsight, packet, patsy, cia,
# Nearest to three: four, six, two, five, seven, eight, nine, zero,
# Nearest to states: nations, kingdom, countries, state, patristic, pennsylvania, governments, madness,
# Nearest to or: and, than, while, like, scriptorium, belonging, any, rubbed,
# Nearest to he: she, it, they, there, we, who, evangelicalism, gaeltacht,
# Nearest to have: had, has, were, are, be, having, require, include,
# Nearest to use: support, most, require, form, mutate, using, guis, phrase,
# Nearest to history: list, deleting, bot, mandibles, renewal, ades, programmer, importance,
# Nearest to six: eight, seven, four, nine, five, three, two, zero,
# Nearest to when: if, where, before, after, while, though, because, however,
# Nearest to th: rd, six, seven, ancien, racetrack, bc, eight, twentieth,
# Nearest to will: would, can, may, could, must, should, might, cannot,
# Nearest to years: days, decades, months, times, year, gbit, hours, fabien,
# Average loss at step 72000: 3.373208
# Average loss at step 74000: 3.353554
# Average loss at step 76000: 3.312124
# Average loss at step 78000: 3.355130
# Average loss at step 80000: 3.377143
# Nearest to with: between, averroes, in, impedance, aaa, cn, lilly, gand,
# Nearest to while: although, though, before, after, when, but, however, and,
# Nearest to who: he, never, now, they, which, deutschlands, barks, still,
# Nearest to war: hindsight, factbook, packet, arab, koestler, bengalis, dove, warthog,
# Nearest to three: six, four, five, seven, two, eight, nine, zero,
# Nearest to states: nations, kingdom, countries, state, us, governments, union, pennsylvania,
# Nearest to or: and, than, while, alsos, unattractive, nothingness, but, des,
# Nearest to he: she, it, they, there, we, gaeltacht, who, evangelicalism,
# Nearest to have: had, has, are, be, were, require, include, having,
# Nearest to use: support, form, require, elders, amounts, because, guis, cause,
# Nearest to history: list, renewal, mandibles, deleting, legendary, bot, beaux, provable,
# Nearest to six: four, eight, seven, five, three, nine, two, zero,
# Nearest to when: before, after, if, where, during, while, though, although,
# Nearest to th: rd, eight, five, six, twentieth, racetrack, bc, nd,
# Nearest to will: would, could, can, may, should, must, might, cannot,
# Nearest to years: days, months, decades, times, weeks, year, hours, gbit,
# Average loss at step 82000: 3.409789
# Average loss at step 84000: 3.413433
# Average loss at step 86000: 3.391741
# Average loss at step 88000: 3.352941
# Average loss at step 90000: 3.366697
# Nearest to with: between, in, by, using, without, impedance, averroes, upbeat,
# Nearest to while: although, before, when, though, after, during, were, and,
# Nearest to who: he, which, she, now, often, thomas, barks, never,
# Nearest to war: factbook, packet, during, arab, hindsight, etymological, koestler, dove,
# Nearest to three: four, five, two, eight, seven, six, nine, zero,
# Nearest to states: nations, kingdom, us, state, governments, countries, union, culminated,
# Nearest to or: and, hysteria, titanium, than, alsos, while, piran, diminution,
# Nearest to he: she, it, they, there, who, we, gaeltacht, ejective,
# Nearest to have: had, has, were, are, contain, having, be, require,
# Nearest to use: support, hierarchy, guis, elders, most, amounts, application, mutate,
# Nearest to history: list, renewal, bot, mandibles, period, fortieth, usage, deleting,
# Nearest to six: eight, seven, four, five, nine, three, two, zero,
# Nearest to when: before, after, if, while, where, although, though, until,
# Nearest to th: rd, eight, seven, nine, fifth, racetrack, five, twentieth,
# Nearest to will: would, could, can, may, should, must, might, cannot,
# Nearest to years: days, decades, months, times, weeks, hours, year, minutes,
# Average loss at step 92000: 3.401376
# Average loss at step 94000: 3.257801
# Average loss at step 96000: 3.355633
# Average loss at step 98000: 3.244270
# Average loss at step 100000: 3.358555
# Nearest to with: between, using, averroes, sidonia, in, through, toward, dmc,
# Nearest to while: although, when, though, before, after, during, or, but,
# Nearest to who: he, she, never, now, that, often, which, also,
# Nearest to war: packet, wars, factbook, hindsight, bengalis, adverbial, etymological, tanistry,
# Nearest to three: four, five, six, two, seven, eight, nine, zero,
# Nearest to states: nations, kingdom, state, us, countries, governments, catcher, union,
# Nearest to or: and, than, while, piran, alloying, viking, pics, knitting,
# Nearest to he: she, it, they, there, who, we, gaeltacht, never,
# Nearest to have: had, has, contain, are, require, were, include, be,
# Nearest to use: support, application, subspace, form, hierarchy, guis, amounts, need,
# Nearest to history: list, mandibles, renewal, deleting, bot, bottled, metabolize, bakkers,
# Nearest to six: four, seven, eight, five, nine, three, two, zero,
# Nearest to when: while, if, before, after, where, although, though, because,
# Nearest to th: rd, nd, fifth, racetrack, bc, ft, eight, st,
# Nearest to will: would, could, can, may, must, should, might, cannot,
# Nearest to years: days, decades, months, hours, weeks, year, times, minutes,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
    assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
    pylab.figure(figsize=(20, 20))  # in inches
    for i, label in enumerate(labels):
        x, y = embeddings[i,:]
        pylab.scatter(x, y)
        pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points', ha='right', va='bottom')
    pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %% [markdown]
# #### Меняется только то, что в skip-gram мы из слова пробовали сгенерить контекст, а в CBOW из контекста - слово.

# %%
data_index = 0

def generate_CBOW_batch(batch_size, num_skips, skip_window):
    global data_index
    assert batch_size % num_skips == 0
    assert num_skips <= 2 * skip_window
    batch = np.ndarray(shape=(batch_size), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    span = 2 * skip_window + 1 # [ skip_window target skip_window ]
    buffer = collections.deque(maxlen=span)
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    for i in range(batch_size // num_skips):
        target = skip_window  # target label at the center of the buffer
        targets_to_avoid = [ skip_window ]
        for j in range(num_skips):
            while target in targets_to_avoid:
                target = random.randint(0, span - 1)
            targets_to_avoid.append(target)
            batch[i * num_skips + j] = buffer[target]
            labels[i * num_skips + j, 0] = buffer[skip_window]
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'a', 'originated', 'term', 'as', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['term', 'anarchism', 'originated', 'a', 'of', 'term', 'originated', 'as']

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

    # Input data.
    train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
    # Variables.
    embeddings = tf.Variable(tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    softmax_weights = tf.Variable(
        tf.truncated_normal([vocabulary_size, embedding_size],stddev=1.0 / math.sqrt(embedding_size))
    )
    softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
    # Model.
    # Look up embeddings for inputs.
    embed = tf.nn.embedding_lookup(embeddings, train_dataset)
    # Compute the softmax loss, using a sample of the negative labels each time.
    loss = tf.reduce_mean(
        tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                                   labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

    # Optimizer.
    # Note: The optimizer will optimize the softmax_weights AND the embeddings.
    # This is because the embeddings are defined as a variable quantity and the
    # optimizer's `minimize` method will by default modify all variable quantities 
    # that contribute to the tensor it is passed.
    # See docs on `tf.train.Optimizer.minimize()` for more details.
    optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
    # Compute the similarity between minibatch examples and all embeddings.
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings, valid_dataset)
    similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
# %%time
num_steps = 100001

with tf.Session(graph=graph) as session:
    tf.global_variables_initializer().run()
    print('Initialized')
    average_loss = 0
    for step in range(num_steps):
        batch_data, batch_labels = generate_CBOW_batch(batch_size, num_skips, skip_window)
        feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
        _, l = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += l
        if step % 2000 == 0:
            if step > 0:
                average_loss = average_loss / 2000
            # The average loss is an estimate of the loss over the last 2000 batches.
            print('Average loss at step %d: %f' % (step, average_loss))
            average_loss = 0
        # note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 10000 == 0:
            sim = similarity.eval()
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8 # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k+1]
                log = 'Nearest to %s:' % valid_word
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log = '%s %s,' % (log, close_word)
                print(log)
    final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.271007
# Nearest to but: orfeo, struggle, bolder, harcourt, blade, knob, chatter, complicating,
# Nearest to see: wells, broadsword, milder, bevan, bukovina, oneworld, caxton, craton,
# Nearest to one: hughes, medals, branded, unenforceable, minicomputer, learnt, nutritious, unclassified,
# Nearest to which: kowloon, cardano, brubeck, killian, database, swnts, itinerary, carolinas,
# Nearest to has: block, argued, learners, tica, thurman, roadie, senussi, majestic,
# Nearest to was: upsurge, zero, neyman, dipole, easier, geographer, wine, weather,
# Nearest to three: marketplace, guests, malvinas, preface, depreciation, tattoos, winfield, bangkok,
# Nearest to over: airfields, austerlitz, shab, abakan, orator, palmerston, brasses, gasolines,
# Nearest to had: unfccc, starr, fused, kryptonite, aren, dogmatically, hundreds, angora,
# Nearest to at: rss, ahura, discarding, foss, gyatso, whimsical, ciii, sediments,
# Nearest to that: cinder, bainbridge, cabling, pgs, undue, bon, deluge, otimes,
# Nearest to they: nanotubes, counterintuitive, tamazight, emanated, sans, staley, babylonian, galatians,
# Nearest to more: nme, deep, saxophonist, musicologists, osmond, murad, planks, treblinka,
# Nearest to may: tested, abhidharma, oracles, belt, jealousy, oktoberfest, discontinue, noaa,
# Nearest to while: film, resizing, hermaphroditus, treize, computability, meets, regulates, embassies,
# Nearest to world: appeasement, honorable, netting, starting, translator, pythons, leipzig, sassanians,
# Average loss at step 2000: 4.365967
# Average loss at step 4000: 3.869060
# Average loss at step 6000: 3.788225
# Average loss at step 8000: 3.695367
# Average loss at step 10000: 3.618822
# Nearest to but: animation, that, anisotropic, however, sapporo, he, it, depatie,
# Nearest to see: wells, may, succeeded, mora, milder, caxton, demiurge, bevan,
# Nearest to one: two, four, three, eight, six, seven, backstreet, enjoying,
# Nearest to which: that, this, it, also, schmitz, pressed, who, arrowhead,
# Nearest to has: had, is, have, was, conceit, shuster, cu, focal,
# Nearest to was: is, had, by, were, has, are, be, been,
# Nearest to three: four, six, seven, five, eight, two, nine, zero,
# Nearest to over: tobacco, radioactivity, semigroup, plume, logic, palmerston, deserve, looms,
# Nearest to had: has, have, was, were, conceit, donating, molecule, kaye,
# Nearest to at: in, on, forcible, by, discarding, of, aino, ahura,
# Nearest to that: which, brady, it, this, but, what, lateran, unspoken,
# Nearest to they: he, we, it, tamazight, there, not, you, she,
# Nearest to more: less, deep, attorney, ncs, predating, ornithologists, peabody, formally,
# Nearest to may: can, tested, abhidharma, regal, see, belt, might, safin,
# Nearest to while: film, provisions, undecided, cindy, meets, injunction, multiplexed, ales,
# Nearest to world: first, starting, conduct, appeasement, wane, mae, cows, caligula,
# Average loss at step 12000: 3.610514
# Average loss at step 14000: 3.574250
# Average loss at step 16000: 3.416603
# Average loss at step 18000: 3.460284
# Average loss at step 20000: 3.539983
# Nearest to but: however, and, that, shipments, when, which, was, is,
# Nearest to see: provides, may, citizenry, demiurge, wells, appoint, shameful, succeeded,
# Nearest to one: two, four, three, seven, six, eight, five, nine,
# Nearest to which: this, that, who, it, also, reintroducing, eamon, barrister,
# Nearest to has: had, have, was, is, fool, juan, cu, shuster,
# Nearest to was: is, has, had, were, became, carte, be, been,
# Nearest to three: six, four, five, seven, two, eight, zero, nine,
# Nearest to over: semigroup, plume, discarding, prefaces, say, tobacco, carbonic, maggie,
# Nearest to had: has, have, was, were, did, shed, molecule, conceit,
# Nearest to at: in, forcible, after, from, surrounding, fawlty, during, into,
# Nearest to that: which, but, tarot, brady, what, scrolling, lateran, because,
# Nearest to they: he, we, there, she, you, it, not, who,
# Nearest to more: less, deep, rather, very, predating, peabody, ncs, most,
# Nearest to may: can, would, might, should, will, could, must, abhidharma,
# Nearest to while: provisions, when, undecided, film, but, cindy, are, where,
# Nearest to world: conduct, mae, starting, uta, appeasement, zapatista, mohenjo, caligula,
# Average loss at step 22000: 3.502027
# Average loss at step 24000: 3.492381
# Average loss at step 26000: 3.483879
# Average loss at step 28000: 3.480095
# Average loss at step 30000: 3.507920
# Nearest to but: however, when, although, while, which, and, that, inositol,
# Nearest to see: tabled, appoint, citizenry, may, mysql, mora, falcone, ncsa,
# Nearest to one: two, seven, four, eight, three, five, nine, six,
# Nearest to which: this, what, that, who, but, sorbian, pressed, also,
# Nearest to has: had, have, is, was, juan, single, having, does,
# Nearest to was: is, were, had, has, been, became, by, when,
# Nearest to three: four, five, seven, two, six, eight, nine, zero,
# Nearest to over: discarding, acquaintance, idiosyncrasies, semigroup, prefaces, plume, fonni, tobacco,
# Nearest to had: has, have, was, were, naturalized, portable, shed, harvesting,
# Nearest to at: in, fawlty, during, abkhaz, forcible, on, interviewer, softly,
# Nearest to that: which, what, beaulieu, but, this, brady, arrowhead, hogeschool,
# Nearest to they: we, there, he, it, you, she, not, who,
# Nearest to more: less, very, rather, deep, most, predating, surround, formally,
# Nearest to may: can, would, should, will, could, might, must, see,
# Nearest to while: but, when, provisions, where, mummification, undecided, cindy, lowlands,
# Nearest to world: conduct, brugha, valentino, zapatista, caligula, uta, mohenjo, mae,
# Average loss at step 32000: 3.504731
# Average loss at step 34000: 3.494074
# Average loss at step 36000: 3.453544
# Average loss at step 38000: 3.302370
# Average loss at step 40000: 3.429885
# Nearest to but: however, which, and, while, although, though, evokes, that,
# Nearest to see: refer, citizenry, may, provides, mysql, tabled, include, feininger,
# Nearest to one: seven, four, two, six, eight, five, nine, three,
# Nearest to which: that, this, who, but, what, also, there, however,
# Nearest to has: had, have, was, is, juan, reggaeton, does, cc,
# Nearest to was: is, were, had, has, became, been, be, when,
# Nearest to three: four, five, seven, six, two, eight, nine, zero,
# Nearest to over: nearly, discarding, asdb, dickinson, say, plume, through, carbonic,
# Nearest to had: has, have, was, were, having, molecule, since, already,
# Nearest to at: during, fawlty, on, in, smallest, under, ahura, dorian,
# Nearest to that: which, what, this, brady, beaulieu, but, however, posits,
# Nearest to they: we, he, there, you, she, it, these, milo,
# Nearest to more: less, most, very, rather, formally, deep, so, predating,
# Nearest to may: can, would, will, could, should, might, must, cannot,
# Nearest to while: when, where, but, after, although, and, wiki, lowlands,
# Nearest to world: cheesemaking, atlanta, jump, valentino, uta, mae, battle, timescale,
# Average loss at step 42000: 3.430546
# Average loss at step 44000: 3.452122
# Average loss at step 46000: 3.451714
# Average loss at step 48000: 3.353511
# Average loss at step 50000: 3.387037
# Nearest to but: however, although, though, and, while, when, that, which,
# Nearest to see: include, refer, tabled, mysql, falcone, according, provides, ncsa,
# Nearest to one: two, eight, six, seven, four, nine, three, five,
# Nearest to which: that, this, also, what, who, often, however, generally,
# Nearest to has: had, have, was, is, meltzer, having, juan, scarred,
# Nearest to was: is, were, has, had, became, been, be, categorized,
# Nearest to three: six, seven, four, eight, five, nine, two, zero,
# Nearest to over: through, eisteddfod, on, discarding, nearly, dickinson, geer, austerlitz,
# Nearest to had: has, have, was, having, were, already, shuster, naturalized,
# Nearest to at: during, fawlty, in, undersecretary, under, kaltenbrunner, intercept, near,
# Nearest to that: which, however, what, brady, this, but, because, beaulieu,
# Nearest to they: we, there, he, you, she, it, who, milo,
# Nearest to more: less, very, most, rather, formally, fairly, henriette, laureates,
# Nearest to may: can, would, will, should, could, might, must, cannot,
# Nearest to while: when, where, although, but, after, however, and, before,
# Nearest to world: jump, valentino, uta, atlanta, cheesemaking, prisoners, timescale, mackay,
# Average loss at step 52000: 3.437501
# Average loss at step 54000: 3.428433
# Average loss at step 56000: 3.437661
# Average loss at step 58000: 3.399195
# Average loss at step 60000: 3.392240
# Nearest to but: however, and, although, though, falsification, when, than, while,
# Nearest to see: include, but, tabled, refer, mysql, citizenry, can, finno,
# Nearest to one: two, seven, four, eight, six, five, three, nine,
# Nearest to which: that, this, what, who, however, generally, still, odessa,
# Nearest to has: had, have, is, was, juan, having, meltzer, violins,
# Nearest to was: is, had, became, were, has, be, axles, although,
# Nearest to three: five, four, six, eight, seven, two, nine, zero,
# Nearest to over: through, around, eisteddfod, between, nearly, discarding, about, mataram,
# Nearest to had: has, have, was, were, having, did, attempted, been,
# Nearest to at: during, fawlty, in, under, after, near, smallest, oral,
# Nearest to that: which, what, this, however, brady, beaulieu, lateran, here,
# Nearest to they: we, there, he, you, she, it, not, milo,
# Nearest to more: less, very, rather, most, smaller, better, henriette, formally,
# Nearest to may: can, would, should, will, could, might, must, cannot,
# Nearest to while: when, although, before, after, where, if, but, though,
# Nearest to world: valentino, prisoners, caligula, jump, neolithic, post, cheesemaking, brugha,
# Average loss at step 62000: 3.241954
# Average loss at step 64000: 3.252434
# Average loss at step 66000: 3.408008
# Average loss at step 68000: 3.396619
# Average loss at step 70000: 3.359145
# Nearest to but: however, although, though, while, which, that, and, if,
# Nearest to see: include, mysql, but, according, list, caroline, refer, provides,
# Nearest to one: seven, two, six, four, five, nine, eight, three,
# Nearest to which: that, this, what, also, but, however, still, who,
# Nearest to has: had, have, is, was, impressive, although, bubba, since,
# Nearest to was: is, has, had, were, became, been, generators, be,
# Nearest to three: six, four, five, seven, two, eight, nine, zero,
# Nearest to over: around, through, about, discarding, asdb, nearly, on, across,
# Nearest to had: have, has, was, were, having, incited, attempted, shuster,
# Nearest to at: fawlty, undersecretary, oral, after, near, elusive, during, catalogs,
# Nearest to that: which, what, however, this, but, brady, where, safe,
# Nearest to they: we, there, he, you, it, she, these, milo,
# Nearest to more: less, very, most, rather, smaller, fairly, quite, extremely,
# Nearest to may: can, would, will, should, could, might, must, cannot,
# Nearest to while: although, when, where, however, if, before, but, after,
# Nearest to world: valentino, post, recovery, launch, caligula, prisoners, jump, hermetical,
# Average loss at step 72000: 3.375487
# Average loss at step 74000: 3.346317
# Average loss at step 76000: 3.319584
# Average loss at step 78000: 3.348890
# Average loss at step 80000: 3.378078
# Nearest to but: however, although, while, though, and, or, see, which,
# Nearest to see: include, but, list, refer, according, describe, includes, citizenry,
# Nearest to one: seven, six, two, four, three, eight, five, nine,
# Nearest to which: that, this, what, who, currently, also, usually, but,
# Nearest to has: had, have, is, was, although, meltzer, impressive, juan,
# Nearest to was: is, became, has, had, were, being, been, carte,
# Nearest to three: six, four, five, seven, eight, two, nine, zero,
# Nearest to over: around, through, across, into, about, eisteddfod, graced, between,
# Nearest to had: have, has, was, were, having, impressive, incited, attempted,
# Nearest to at: in, during, enders, tying, kaltenbrunner, elusive, forcible, himalaya,
# Nearest to that: which, however, what, brady, where, wiring, currently, posits,
# Nearest to they: we, he, you, there, she, it, these, plebs,
# Nearest to more: less, very, most, rather, fairly, quite, smaller, extremely,
# Nearest to may: can, would, could, will, should, might, must, does,
# Nearest to while: although, when, though, however, but, after, before, where,
# Nearest to world: jump, valentino, country, recovery, rookie, tetrahedra, cession, neolithic,
# Average loss at step 82000: 3.407981
# Average loss at step 84000: 3.414917
# Average loss at step 86000: 3.387667
# Average loss at step 88000: 3.353771
# Average loss at step 90000: 3.366418
# Nearest to but: however, although, and, while, though, or, he, which,
# Nearest to see: include, list, includes, refer, references, segments, links, according,
# Nearest to one: seven, four, two, eight, six, five, three, nine,
# Nearest to which: that, this, what, also, usually, actually, currently, these,
# Nearest to has: had, have, is, was, having, violins, meltzer, since,
# Nearest to was: is, had, were, became, been, has, be, being,
# Nearest to three: five, two, four, seven, eight, six, nine, zero,
# Nearest to over: around, through, awakening, nearly, across, discarding, about, eisteddfod,
# Nearest to had: has, have, was, were, having, incited, been, attempted,
# Nearest to at: during, near, under, amending, in, antiderivative, after, lan,
# Nearest to that: which, however, what, brady, defunct, lampooned, whom, wiring,
# Nearest to they: we, he, there, you, she, it, not, plebs,
# Nearest to more: less, very, most, rather, fairly, better, quite, smaller,
# Nearest to may: can, could, would, should, will, might, must, cannot,
# Nearest to while: although, when, before, but, though, where, after, were,
# Nearest to world: recovery, jump, tetrahedra, neolithic, advocated, prisoners, hermetical, cheesemaking,
# Average loss at step 92000: 3.397138
# Average loss at step 94000: 3.255369
# Average loss at step 96000: 3.356345
# Average loss at step 98000: 3.244985
# Average loss at step 100000: 3.357150
# Nearest to but: although, however, and, though, while, which, when, almost,
# Nearest to see: includes, refer, include, references, list, links, external, refers,
# Nearest to one: two, seven, nine, four, six, eight, three, five,
# Nearest to which: that, this, what, usually, these, also, pressed, actually,
# Nearest to has: had, have, is, was, having, since, meltzer, includes,
# Nearest to was: is, has, became, were, had, been, although, be,
# Nearest to three: five, four, two, six, seven, eight, nine, zero,
# Nearest to over: around, nearly, through, eisteddfod, awakening, across, carbonic, between,
# Nearest to had: has, have, was, having, were, is, naturalized, did,
# Nearest to at: during, on, in, after, under, near, when, undersecretary,
# Nearest to that: which, however, what, brady, wiring, where, nursia, this,
# Nearest to they: we, he, there, you, she, it, not, plebs,
# Nearest to more: less, most, very, better, smaller, extremely, rather, quite,
# Nearest to may: can, should, could, must, might, would, will, cannot,
# Nearest to while: when, although, though, where, before, after, but, and,
# Nearest to world: neolithic, hemlock, jump, tetrahedra, country, recovery, advocated, penetrate,
# CPU times: user 8min 29s, sys: 1min 25s, total: 9min 54s
# Wall time: 5min 14s

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
    assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
    pylab.figure(figsize=(20, 20))  # in inches
    for i, label in enumerate(labels):
        x, y = embeddings[i,:]
        pylab.scatter(x, y)
        pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points', ha='right', va='bottom')
    pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
