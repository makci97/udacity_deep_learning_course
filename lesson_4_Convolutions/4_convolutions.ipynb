# %% [markdown]
# Deep Learning
# =============
#
# Assignment 4
# ------------
#
# Previously in `2_fullyconnected.ipynb` and `3_regularization.ipynb`, we trained fully connected networks to classify [notMNIST](http://yaroslavvb.blogspot.com/2011/09/notmnist-dataset.html) characters.
#
# The goal of this assignment is make the neural network convolutional.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
from __future__ import print_function
import numpy as np
import tensorflow as tf
from six.moves import cPickle as pickle
from six.moves import range

# %%
pickle_file = 'notMNIST.pickle'

with open(pickle_file, 'rb') as f:
    save = pickle.load(f)
    train_dataset = save['train_dataset']
    train_labels = save['train_labels']
    valid_dataset = save['valid_dataset']
    valid_labels = save['valid_labels']
    test_dataset = save['test_dataset']
    test_labels = save['test_labels']
    del save  # hint to help gc free up memory
    print('Training set', train_dataset.shape, train_labels.shape)
    print('Validation set', valid_dataset.shape, valid_labels.shape)
    print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# Training set (200000, 28, 28) (200000,)
# Validation set (10000, 28, 28) (10000,)
# Test set (10000, 28, 28) (10000,)

# %% [markdown]
# Reformat into a TensorFlow-friendly shape:
# - convolutions need the image data formatted as a cube (width by height by #channels)
# - labels as float 1-hot encodings.

# %%
image_size = 28
num_labels = 10
num_channels = 1 # grayscale

import numpy as np

def reformat(dataset, labels):
    dataset = dataset.reshape((-1, image_size, image_size, num_channels)).astype(np.float32)
    labels = (np.arange(num_labels) == labels[:,None]).astype(np.float32)
    return dataset, labels

train_dataset, train_labels = reformat(train_dataset, train_labels)
valid_dataset, valid_labels = reformat(valid_dataset, valid_labels)
test_dataset, test_labels = reformat(test_dataset, test_labels)

print('Training set', train_dataset.shape, train_labels.shape)
print('Validation set', valid_dataset.shape, valid_labels.shape)
print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# Training set (200000, 28, 28, 1) (200000, 10)
# Validation set (10000, 28, 28, 1) (10000, 10)
# Test set (10000, 28, 28, 1) (10000, 10)

# %%
def accuracy(predictions, labels):
    return (100.0 * np.sum(np.argmax(predictions, 1) == np.argmax(labels, 1)) / predictions.shape[0])

# %% [markdown]
# Let's build a small network with two convolutional layers, followed by one fully connected layer. Convolutional networks are more expensive computationally, so we'll limit its depth and number of fully connected nodes.

# %%
batch_size = 16
patch_size = 5
depth = 16
num_hidden = 64

graph = tf.Graph()

with graph.as_default():

    # Input data.
    tf_train_dataset = tf.placeholder(tf.float32, shape=(batch_size, image_size, image_size, num_channels))
    tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
    tf_valid_dataset = tf.constant(valid_dataset)
    tf_test_dataset = tf.constant(test_dataset)
  
    # Variables.
    layer1_weights = tf.Variable(tf.truncated_normal([patch_size, patch_size, num_channels, depth], stddev=0.1))
    layer1_biases = tf.Variable(tf.zeros([depth]))
    layer2_weights = tf.Variable(tf.truncated_normal([patch_size, patch_size, depth, depth], stddev=0.1))
    layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
    layer3_weights = tf.Variable(tf.truncated_normal(
        [image_size // 4 * image_size // 4 * depth, num_hidden], stddev=0.1))
    layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
    layer4_weights = tf.Variable(tf.truncated_normal([num_hidden, num_labels], stddev=0.1))
    layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  
    # Model.
    def model(data):
        conv = tf.nn.conv2d(data, layer1_weights, [1, 2, 2, 1], padding='SAME')
        hidden = tf.nn.relu(conv + layer1_biases)
        conv = tf.nn.conv2d(hidden, layer2_weights, [1, 2, 2, 1], padding='SAME')
        hidden = tf.nn.relu(conv + layer2_biases)
        shape = hidden.get_shape().as_list()
        reshape = tf.reshape(hidden, [shape[0], shape[1] * shape[2] * shape[3]])
        hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
        return tf.matmul(hidden, layer4_weights) + layer4_biases
  
    # Training computation.
    logits = model(tf_train_dataset)
    loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels=tf_train_labels, logits=logits))
    
    # Optimizer.
    optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)

    # Predictions for the training, validation, and test data.
    train_prediction = tf.nn.softmax(logits)
    valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
    test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %%
num_steps = 1001

with tf.Session(graph=graph) as session:
    tf.global_variables_initializer().run()
    print('Initialized')
    for step in range(num_steps):
        offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
        batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
        batch_labels = train_labels[offset:(offset + batch_size), :]
        feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
        _, l, predictions = session.run(
        [optimizer, loss, train_prediction], feed_dict=feed_dict)
        if (step % 50 == 0):
            print('Minibatch loss at step %d: %f' % (step, l))
            print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
            print('Validation accuracy: %.1f%% \n' % accuracy(
            valid_prediction.eval(), valid_labels))
    print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 3.812750
# Minibatch accuracy: 6.2%
# Validation accuracy: 10.0%
#
# Minibatch loss at step 50: 1.481008
# Minibatch accuracy: 50.0%
# Validation accuracy: 61.3%
#
# Minibatch loss at step 100: 0.561620
# Minibatch accuracy: 87.5%
# Validation accuracy: 74.3%
#
# Minibatch loss at step 150: 0.754526
# Minibatch accuracy: 68.8%
# Validation accuracy: 73.8%
#
# Minibatch loss at step 200: 0.342321
# Minibatch accuracy: 93.8%
# Validation accuracy: 78.1%
#
# Minibatch loss at step 250: 0.699854
# Minibatch accuracy: 81.2%
# Validation accuracy: 77.9%
#
# Minibatch loss at step 300: 1.145808
# Minibatch accuracy: 62.5%
# Validation accuracy: 78.7%
#
# Minibatch loss at step 350: 0.967769
# Minibatch accuracy: 68.8%
# Validation accuracy: 80.0%
#
# Minibatch loss at step 400: 0.746205
# Minibatch accuracy: 81.2%
# Validation accuracy: 80.3%
#
# Minibatch loss at step 450: 0.518180
# Minibatch accuracy: 87.5%
# Validation accuracy: 80.9%
#
# Minibatch loss at step 500: 0.531196
# Minibatch accuracy: 87.5%
# Validation accuracy: 80.7%
#
# Minibatch loss at step 550: 0.061582
# Minibatch accuracy: 100.0%
# Validation accuracy: 81.8%
#
# Minibatch loss at step 600: 0.617967
# Minibatch accuracy: 81.2%
# Validation accuracy: 80.9%
#
# Minibatch loss at step 650: 0.746381
# Minibatch accuracy: 75.0%
# Validation accuracy: 81.2%
#
# Minibatch loss at step 700: 0.460636
# Minibatch accuracy: 81.2%
# Validation accuracy: 81.1%
#
# Minibatch loss at step 750: 0.203399
# Minibatch accuracy: 93.8%
# Validation accuracy: 82.4%
#
# Minibatch loss at step 800: 0.873240
# Minibatch accuracy: 75.0%
# Validation accuracy: 82.1%
#
# Minibatch loss at step 850: 0.331032
# Minibatch accuracy: 93.8%
# Validation accuracy: 82.6%
#
# Minibatch loss at step 900: 1.105283
# Minibatch accuracy: 75.0%
# Validation accuracy: 82.7%
#
# Minibatch loss at step 950: 0.922396
# Minibatch accuracy: 75.0%
# Validation accuracy: 82.7%
#
# Minibatch loss at step 1000: 0.695933
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.7%
#
# Test accuracy: 88.7%

# %% [markdown]
# ---
# Problem 1
# ---------
#
# The convolutional model above uses convolutions with stride 2 to reduce the dimensionality. Replace the strides by a max pooling operation (`nn.max_pool()`) of stride 2 and kernel size 2.
#
# ---

# %%
batch_size = 16
patch_size = 5
depth = 16
num_hidden = 64

graph = tf.Graph()

with graph.as_default():

    # Input data.
    tf_train_dataset = tf.placeholder(tf.float32, shape=(batch_size, image_size, image_size, num_channels))
    tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
    tf_valid_dataset = tf.constant(valid_dataset)
    tf_test_dataset = tf.constant(test_dataset)
  
    # Variables.
    layer1_weights = tf.Variable(tf.truncated_normal([patch_size, patch_size, num_channels, depth], stddev=0.1))
    layer1_biases = tf.Variable(tf.zeros([depth]))
    layer2_weights = tf.Variable(tf.truncated_normal([patch_size, patch_size, depth, depth], stddev=0.1))
    layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
    layer3_weights = tf.Variable(tf.truncated_normal(
        [image_size // 4 * image_size // 4 * depth, num_hidden], stddev=0.1))
    layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
    layer4_weights = tf.Variable(tf.truncated_normal([num_hidden, num_labels], stddev=0.1))
    layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  
    # Model.
    def model(data):
        conv = tf.nn.conv2d(data, layer1_weights, [1, 1, 1, 1], padding='SAME')
        hidden = tf.nn.relu(conv + layer1_biases)
        pool = tf.nn.max_pool(hidden, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='SAME')
        conv = tf.nn.conv2d(pool, layer2_weights, [1, 1, 1, 1], padding='SAME')
        hidden = tf.nn.relu(conv + layer2_biases)
        pool = tf.nn.max_pool(hidden, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='SAME')
        shape = pool.get_shape().as_list()
        reshape = tf.reshape(pool, [shape[0], shape[1] * shape[2] * shape[3]])
        hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
        return tf.matmul(hidden, layer4_weights) + layer4_biases
  
    # Training computation.
    logits = model(tf_train_dataset)
    loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels=tf_train_labels, logits=logits))
    
    # Optimizer.
    optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)

    # Predictions for the training, validation, and test data.
    train_prediction = tf.nn.softmax(logits)
    valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
    test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %%
num_steps = 1001

with tf.Session(graph=graph) as session:
    tf.global_variables_initializer().run()
    print('Initialized')
    for step in range(num_steps):
        offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
        batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
        batch_labels = train_labels[offset:(offset + batch_size), :]
        feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
        _, l, predictions = session.run(
        [optimizer, loss, train_prediction], feed_dict=feed_dict)
        if (step % 50 == 0):
            print('Minibatch loss at step %d: %f' % (step, l))
            print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
            print('Validation accuracy: %.1f%% \n' % accuracy(
            valid_prediction.eval(), valid_labels))
    print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 3.758843
# Minibatch accuracy: 6.2%
# Validation accuracy: 10.0%
#
# Minibatch loss at step 50: 2.303280
# Minibatch accuracy: 6.2%
# Validation accuracy: 10.1%
#
# Minibatch loss at step 100: 2.190571
# Minibatch accuracy: 25.0%
# Validation accuracy: 20.0%
#
# Minibatch loss at step 150: 1.315684
# Minibatch accuracy: 43.8%
# Validation accuracy: 40.7%
#
# Minibatch loss at step 200: 0.803315
# Minibatch accuracy: 75.0%
# Validation accuracy: 71.3%
#
# Minibatch loss at step 250: 1.202127
# Minibatch accuracy: 62.5%
# Validation accuracy: 77.0%
#
# Minibatch loss at step 300: 1.405955
# Minibatch accuracy: 56.2%
# Validation accuracy: 69.6%
#
# Minibatch loss at step 350: 0.945617
# Minibatch accuracy: 68.8%
# Validation accuracy: 79.4%
#
# Minibatch loss at step 400: 0.773259
# Minibatch accuracy: 81.2%
# Validation accuracy: 81.1%
#
# Minibatch loss at step 450: 0.485566
# Minibatch accuracy: 87.5%
# Validation accuracy: 80.3%
#
# Minibatch loss at step 500: 0.547375
# Minibatch accuracy: 87.5%
# Validation accuracy: 81.0%
#
# Minibatch loss at step 550: 0.113422
# Minibatch accuracy: 93.8%
# Validation accuracy: 82.1%
#
# Minibatch loss at step 600: 0.573534
# Minibatch accuracy: 87.5%
# Validation accuracy: 81.9%
#
# Minibatch loss at step 650: 0.785684
# Minibatch accuracy: 75.0%
# Validation accuracy: 83.0%
#
# Minibatch loss at step 700: 0.438856
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.0%
#
# Minibatch loss at step 750: 0.184963
# Minibatch accuracy: 93.8%
# Validation accuracy: 83.3%
#
# Minibatch loss at step 800: 1.128259
# Minibatch accuracy: 62.5%
# Validation accuracy: 82.8%
#
# Minibatch loss at step 850: 0.348717
# Minibatch accuracy: 93.8%
# Validation accuracy: 83.2%
#
# Minibatch loss at step 900: 0.865124
# Minibatch accuracy: 75.0%
# Validation accuracy: 83.2%
#
# Minibatch loss at step 950: 1.020791
# Minibatch accuracy: 68.8%
# Validation accuracy: 82.4%
#
# Minibatch loss at step 1000: 0.683762
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.4%
#
# Test accuracy: 89.8%

# %% [markdown]
# ---
# Problem 2
# ---------
#
# Try to get the best performance you can using a convolutional net. Look for example at the classic [LeNet5](http://yann.lecun.com/exdb/lenet/) architecture, adding Dropout, and/or adding learning rate decay.
#
# ---

# %%
batch_size = 172
patch_size = 5
depth = 16*2
num_hidden = 512
keep_prob = 0.5

graph = tf.Graph()

with graph.as_default():

    # Input data.
    tf_train_dataset = tf.placeholder(tf.float32, shape=(batch_size, image_size, image_size, num_channels))
    tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
    tf_valid_dataset = tf.constant(valid_dataset)
    tf_test_dataset = tf.constant(test_dataset)
  
    # Variables.
    global_step = tf.Variable(0)  # count the number of steps taken.
    learning_rate = tf.train.exponential_decay(0.023, global_step, decay_rate=0.99, decay_steps=20)
    alpha = learning_rate/1000
    
    layer1_weights = tf.Variable(tf.truncated_normal([patch_size, patch_size, num_channels, depth], stddev=0.1))
    layer1_biases = tf.Variable(tf.zeros([depth]))
    layer2_weights = tf.Variable(tf.truncated_normal([3, 3, depth, depth*2], stddev=0.1))
    layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth*2]))
    
    layer2_2_weights = tf.Variable(tf.truncated_normal([3, 3, depth*2, depth*3], stddev=0.1))
    layer2_2_biases = tf.Variable(tf.constant(1.0, shape=[depth*3]))
    
    layer3_weights = tf.Variable(tf.truncated_normal(
        [image_size // 4 * image_size // 4  * depth*3, num_hidden], stddev=0.1))
#         [image_size // 4 * image_size // 4 * depth*3, num_hidden], stddev=0.1))
    layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
    layer4_weights = tf.Variable(tf.truncated_normal([num_hidden, num_labels], stddev=0.1))
    layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  
    # Model.
    def model(data, train_mode=False):
        conv = tf.nn.conv2d(data, layer1_weights, [1, 1, 1, 1], padding='SAME')
        hidden = tf.nn.relu(conv + layer1_biases)
        pool = tf.nn.max_pool(hidden, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='SAME')
        norm = tf.nn.local_response_normalization(pool)
        if train_mode:
            norm = tf.nn.dropout(norm, keep_prob=keep_prob)
        conv = tf.nn.conv2d(norm, layer2_weights, [1, 1, 1, 1], padding='SAME')
        hidden = tf.nn.relu(conv + layer2_biases)
        pool = hidden
#         pool = tf.nn.max_pool(hidden, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='SAME')
#         if train_mode:
#             pool = tf.nn.dropout(pool, keep_prob=keep_prob)
            
        conv = tf.nn.conv2d(pool, layer2_2_weights, [1, 1, 1, 1], padding='SAME')
        hidden = tf.nn.relu(conv + layer2_2_biases)
        pool = tf.nn.max_pool(hidden, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='SAME')
        norm = tf.nn.local_response_normalization(pool)
        if train_mode:
            norm = tf.nn.dropout(norm, keep_prob=keep_prob)    
            
        shape = norm.get_shape().as_list()
        reshape = tf.reshape(norm, [shape[0], shape[1] * shape[2] * shape[3]])
        hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
        if train_mode:
            hidden = tf.nn.dropout(hidden, keep_prob=keep_prob)   
        return tf.matmul(hidden, layer4_weights) + layer4_biases
  
    # Training computation.
    logits = model(tf_train_dataset, train_mode=True)
    loss = (tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels=tf_train_labels, logits=logits)) +
        alpha * (tf.nn.l2_loss(layer1_weights) + tf.nn.l2_loss(layer2_weights) + tf.nn.l2_loss(layer2_2_weights) + 
                 tf.nn.l2_loss(layer3_weights) + tf.nn.l2_loss(layer4_weights)))
    
    # Optimizer.
    optimizer = tf.train.GradientDescentOptimizer(learning_rate).minimize(loss, global_step=global_step)

    # Predictions for the training, validation, and test data.
    train_prediction = tf.nn.softmax(logits)
    valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
    test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %%
# %%time
num_steps = 7001

with tf.Session(graph=graph) as session:
    tf.global_variables_initializer().run()
    print('Initialized')
    for step in range(num_steps):
        offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
        batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
        batch_labels = train_labels[offset:(offset + batch_size), :]
        feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
        _, l, predictions = session.run(
        [optimizer, loss, train_prediction], feed_dict=feed_dict)
        if (step % 150 == 0):
            print('Minibatch loss at step %d: %f' % (step, l))
            print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
            print('Validation accuracy: %.1f%%' % accuracy(valid_prediction.eval(), valid_labels))
            print("LR: {}\n".format(learning_rate.eval()))
    print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 11.186455
# Minibatch accuracy: 5.2%
# Validation accuracy: 10.6%
# LR: 0.022988444194197655
#
# Minibatch loss at step 150: 2.252444
# Minibatch accuracy: 35.5%
# Validation accuracy: 60.9%
# LR: 0.021319331601262093
#
# Minibatch loss at step 300: 1.884939
# Minibatch accuracy: 47.1%
# Validation accuracy: 75.2%
# LR: 0.019771408289670944
#
# Minibatch loss at step 450: 1.507717
# Minibatch accuracy: 59.9%
# Validation accuracy: 77.2%
# LR: 0.018335871398448944
#
# Minibatch loss at step 600: 1.350563
# Minibatch accuracy: 69.2%
# Validation accuracy: 79.4%
# LR: 0.01700456626713276
#
# Minibatch loss at step 750: 1.289767
# Minibatch accuracy: 66.9%
# Validation accuracy: 80.8%
# LR: 0.015769923105835915
#
# Minibatch loss at step 900: 1.231631
# Minibatch accuracy: 68.6%
# Validation accuracy: 81.3%
# LR: 0.01462492160499096
#
# Minibatch loss at step 1050: 1.031699
# Minibatch accuracy: 73.3%
# Validation accuracy: 81.3%
# LR: 0.013563055545091629
#
# Minibatch loss at step 1200: 1.153568
# Minibatch accuracy: 71.5%
# Validation accuracy: 81.3%
# LR: 0.012578288093209267
#
# Minibatch loss at step 1350: 0.953812
# Minibatch accuracy: 76.7%
# Validation accuracy: 81.8%
# LR: 0.011665020138025284
#
# Minibatch loss at step 1500: 0.942099
# Minibatch accuracy: 75.0%
# Validation accuracy: 82.3%
# LR: 0.010818063281476498
#
# Minibatch loss at step 1650: 0.924022
# Minibatch accuracy: 75.0%
# Validation accuracy: 82.4%
# LR: 0.010032599791884422
#
# Minibatch loss at step 1800: 1.007002
# Minibatch accuracy: 75.0%
# Validation accuracy: 82.5%
# LR: 0.0093041667714715
#
# Minibatch loss at step 1950: 0.789296
# Minibatch accuracy: 79.1%
# Validation accuracy: 82.7%
# LR: 0.008628622628748417
#
# Minibatch loss at step 2100: 1.019721
# Minibatch accuracy: 72.7%
# Validation accuracy: 82.9%
# LR: 0.008002127520740032
#
# Minibatch loss at step 2250: 1.028376
# Minibatch accuracy: 72.1%
# Validation accuracy: 82.9%
# LR: 0.007421119604259729
#
# Minibatch loss at step 2400: 0.815343
# Minibatch accuracy: 77.3%
# Validation accuracy: 83.0%
# LR: 0.006882297806441784
#
# Minibatch loss at step 2550: 0.805255
# Minibatch accuracy: 76.7%
# Validation accuracy: 83.3%
# LR: 0.006382596679031849
#
# Minibatch loss at step 2700: 0.838916
# Minibatch accuracy: 76.7%
# Validation accuracy: 83.5%
# LR: 0.005919178016483784
#
# Minibatch loss at step 2850: 0.839995
# Minibatch accuracy: 77.3%
# Validation accuracy: 83.4%
# LR: 0.005489406641572714
#
# Minibatch loss at step 3000: 0.726657
# Minibatch accuracy: 80.2%
# Validation accuracy: 83.7%
# LR: 0.005090839695185423
#
# Minibatch loss at step 3150: 0.849647
# Minibatch accuracy: 75.0%
# Validation accuracy: 83.8%
# LR: 0.004721210803836584
#
# Minibatch loss at step 3300: 0.744929
# Minibatch accuracy: 77.9%
# Validation accuracy: 83.8%
# LR: 0.0043784198351204395
#
# Minibatch loss at step 3450: 0.997597
# Minibatch accuracy: 72.1%
# Validation accuracy: 83.7%
# LR: 0.004060517530888319
#
# Minibatch loss at step 3600: 0.643487
# Minibatch accuracy: 83.1%
# Validation accuracy: 83.7%
# LR: 0.0037656971253454685
#
# Minibatch loss at step 3750: 0.769626
# Minibatch accuracy: 79.1%
# Validation accuracy: 83.7%
# LR: 0.00349228223785758
#
# Minibatch loss at step 3900: 0.674977
# Minibatch accuracy: 81.4%
# Validation accuracy: 84.0%
# LR: 0.0032387194223701954
#
# Minibatch loss at step 4050: 0.828811
# Minibatch accuracy: 77.9%
# Validation accuracy: 84.0%
# LR: 0.0030035669915378094
#
# Minibatch loss at step 4200: 0.637214
# Minibatch accuracy: 81.4%
# Validation accuracy: 84.0%
# LR: 0.0027854882646352053
#
# Minibatch loss at step 4350: 0.963105
# Minibatch accuracy: 71.5%
# Validation accuracy: 83.9%
# LR: 0.0025832431856542826
#
# Minibatch loss at step 4500: 0.766329
# Minibatch accuracy: 75.6%
# Validation accuracy: 84.0%
# LR: 0.0023956827353686094
#
# Minibatch loss at step 4650: 0.761099
# Minibatch accuracy: 76.7%
# Validation accuracy: 84.0%
# LR: 0.0022217403165996075
#
# Minibatch loss at step 4800: 0.756619
# Minibatch accuracy: 80.8%
# Validation accuracy: 84.0%
# LR: 0.0020604273304343224
#
# Minibatch loss at step 4950: 0.969769
# Minibatch accuracy: 76.7%
# Validation accuracy: 84.1%
# LR: 0.0019108266569674015
#
# Minibatch loss at step 5100: 0.644983
# Minibatch accuracy: 82.0%
# Validation accuracy: 84.0%
# LR: 0.001772087998688221
#
# Minibatch loss at step 5250: 0.765707
# Minibatch accuracy: 80.8%
# Validation accuracy: 84.1%
# LR: 0.001643422874622047
#
# Minibatch loss at step 5400: 0.713636
# Minibatch accuracy: 78.5%
# Validation accuracy: 84.2%
# LR: 0.0015240994980558753
#
# Minibatch loss at step 5550: 0.847362
# Minibatch accuracy: 78.5%
# Validation accuracy: 84.2%
# LR: 0.001413439866155386
#
# Minibatch loss at step 5700: 0.658301
# Minibatch accuracy: 80.2%
# Validation accuracy: 84.1%
# LR: 0.0013108146376907825
#
# Minibatch loss at step 5850: 0.787801
# Minibatch accuracy: 78.5%
# Validation accuracy: 84.1%
# LR: 0.0012156408047303557
#
# Minibatch loss at step 6000: 0.772590
# Minibatch accuracy: 79.1%
# Validation accuracy: 84.1%
# LR: 0.001127377268858254
#
# Minibatch loss at step 6150: 0.871001
# Minibatch accuracy: 77.9%
# Validation accuracy: 84.2%
# LR: 0.001045522280037403
#
# Minibatch loss at step 6300: 0.732635
# Minibatch accuracy: 79.7%
# Validation accuracy: 84.2%
# LR: 0.0009696104680188
#
# Minibatch loss at step 6450: 0.702365
# Minibatch accuracy: 77.9%
# Validation accuracy: 84.2%
# LR: 0.0008992102812044322
#
# Minibatch loss at step 6600: 0.659010
# Minibatch accuracy: 80.2%
# Validation accuracy: 84.2%
# LR: 0.0008339216583408415
#
# Minibatch loss at step 6750: 0.713239
# Minibatch accuracy: 78.5%
# Validation accuracy: 84.2%
# LR: 0.0007733734673820436
#
# Minibatch loss at step 6900: 0.665907
# Minibatch accuracy: 78.5%
# Validation accuracy: 84.2%
# LR: 0.0007172214100137353
#
# Test accuracy: 90.2%
# CPU times: user 4h 59min 45s, sys: 25min 38s, total: 5h 25min 23s
# Wall time: 1h 55min 38s
